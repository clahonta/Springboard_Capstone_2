# %%
# Imports
import pandas as pd
import pandas_profiling

# %%
# Load data set
data = pd.read_excel('marital_satisfaction_data.xlsx')

# %%
# Notes for cleanup
# delete useless rows
# convert categorical vars
# what to do with questions as col name?
# Out:
#       Country   Sex (1-M, 2-F)   Age  Marriage duration (years)  \
# 0  Item number             1.0   2.0                        3.0
# 1          NaN             NaN   NaN                        NaN
# 2      Brazil              1.0  21.0                        2.0
# 3      Brazil              1.0  29.0                        3.0
# 4      Brazil              1.0  30.0                        7.0
#
#    Number of children  Number of brought up children  \
# 0                 4.0                            5.0
# 1                 NaN                            NaN
# 2                 0.0                            0.0
# 3                 1.0                            0.0
# 4                 0.0                            0.0
#
#    Education (1-no formal education, 2-primary school, 3-secondary school, 4-high school or technical college, 5-bachelor or master degree)   \
# 0                                                6.0
# 1                                                NaN
# ...
