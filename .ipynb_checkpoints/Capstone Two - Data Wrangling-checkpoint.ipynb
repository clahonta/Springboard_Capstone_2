# %%
# Imports
import pandas as pd
import pandas_profiling

# %%
# Load data set
data = pd.read_excel('marital_satisfaction_data.xlsx')

# %%
# Notes for cleanup
# convert categorical vars
# clear useless rows X
# what to do with questions as col name? X

# %%
data = data.drop(index=[1])

# %%
data = data.drop(index=[0])

# %%
col_names = pd.read_csv('col_names.csv')

# %%
col_names = list(col_names)

# %%
data.columns = col_names

# %%
data.head()
# Out:
#    country  sex   age  marriage_duration_years  num_children_total  \
# 2  Brazil   1.0  21.0                      2.0                 0.0
# 3  Brazil   1.0  29.0                      3.0                 1.0
# 4  Brazil   1.0  30.0                      7.0                 0.0
# 5  Brazil   1.0  30.0                      7.0                 1.0
# 6  Brazil   1.0  28.0                      9.0                 0.0
#
#    num_children_inhome  edu_level  material_situation  religion  religiosity  \
# 2                  0.0        5.0                 3.0       1.0          4.0
# 3                  0.0        5.0                 3.0       1.0          6.0
# 4                  0.0        5.0                 3.0       1.0          4.0
# 5                  1.0        5.0                 3.0       1.0          6.0
# 6                  0.0        4.0                 2.0       1.0          5.0
#
#    ...  spouse_satisfaction  relationship_satisfaction  natl_pride_in_parents  \
# 2  ...                  7.0                        7.0                      1
# 3  ...                  6.0                        6.0                      2
# 4  ...                  7.0                        7.0                      2
# 5  ...                  6.0                        6.0                      3
# 6  ...                  6.0                        7.0                      3
#
#    natl_pride_in_children  natl_aging_parents_live_with_children  \
# 2                     1.0                                    1.0
# 3                     1.0                                    1.0
# 4                     1.0                                    2.0
# 5                     1.0                                    1.0
# 6                     2.0                                    3.0
#
#    natl_children_live_at_home_marraige  indv_pride_in_parents  \
# 2                                  1.0                      1
# 3                                  1.0                      1
# 4                                  1.0                      1
# 5                                  2.0                      1
# 6                                  2.0                      1
#
#    indv_pride_in_children  indv_aging_parents_live_with_children  \
# 2                     1.0                                    1.0
# 3                     1.0                                    1.0
# 4                     1.0                                    1.0
# 5                     1.0                                    1.0
# 6                     1.0                                    1.0
#
#    indv_children_live_at_home_marraige
# 2                                  1.0
# 3                                  1.0
# 4                                  1.0
# 5                                  1.0
# 6                                  1.0
#
# [5 rows x 31 columns]

# %%
data = data.reset_index()

# %%
# Only null values are in religion?

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7178 entries, 0 to 7177
# Data columns (total 32 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   index                                  7178 non-null   int64
#  1   country                                7178 non-null   object
#  2   sex                                    7178 non-null   float64
#  3   age                                    7178 non-null   float64
#  4   marriage_duration_years                7178 non-null   float64
#  5   num_children_total                     7178 non-null   float64
#  6   num_children_inhome                    7178 non-null   float64
#  7   edu_level                              7178 non-null   float64
#  8   material_situation                     7178 non-null   float64
#  9   religion                               7092 non-null   float64
#  10  religiosity                            7178 non-null   float64
#  11  pension                                7178 non-null   float64
#  12  enjoy_spouse_company                   7178 non-null   float64
#  13  happiness                              7178 non-null   float64
#  14  spouse_attraction                      7178 non-null   float64
#  15  spouse_enjoy_doing_things_together     7178 non-null   float64
#  16  spouse_enjoy_cuddling                  7178 non-null   float64
#  17  spouse_respect                         7178 non-null   float64
#  18  spouse_pride                           7178 non-null   float64
#  19  spouse_romance                         7178 non-null   float64
#  20  spouse_love                            7178 non-null   float64
#  21  marital_satisfaction                   7178 non-null   float64
#  22  spouse_satisfaction                    7178 non-null   float64
#  23  relationship_satisfaction              7178 non-null   float64
#  24  natl_pride_in_parents                  7178 non-null   object
#  25  natl_pride_in_children                 7178 non-null   float64
#  26  natl_aging_parents_live_with_children  7178 non-null   float64
#  27  natl_children_live_at_home_marraige    7178 non-null   float64
#  28  indv_pride_in_parents                  7178 non-null   object
#  29  indv_pride_in_children                 7178 non-null   float64
#  30  indv_aging_parents_live_with_children  7178 non-null   float64
#  31  indv_children_live_at_home_marraige    7178 non-null   float64
# dtypes: float64(28), int64(1), object(3)
# memory usage: 1.8+ MB

# %%
globe_survey_dict = {1:"Strongly agree",2:"Agree somewhat",3:"Agree slightly",4:"Neither agree nor disagree",5:"Disagree slightly",6:"Disagree somewhat",7:"Disagree strongly"}

# %%
globe_survey_cols = list(data.columns[24:])

# %%
data[globe_survey_cols] = data[globe_survey_cols].replace(globe_survey_dict)

# %%
mrq_dict = {1:"Yes",2:"Rather yes",3:"Neither yes or no",4:"Rather no",5:"No"}

# %%
mrq_cols = list(data.columns[12:21])

# %%
data[mrq_cols] = data[mrq_cols].replace(mrq_dict)

# %%
data['sex'] = data['sex'].replace({1:"Male",2:"Female"})

# %%
data.head()
# Out:
#    index  country   sex   age  marriage_duration_years  num_children_total  \
# 0      2  Brazil   Male  21.0                      2.0                 0.0
# 1      3  Brazil   Male  29.0                      3.0                 1.0
# 2      4  Brazil   Male  30.0                      7.0                 0.0
# 3      5  Brazil   Male  30.0                      7.0                 1.0
# 4      6  Brazil   Male  28.0                      9.0                 0.0
#
#    num_children_inhome  edu_level  material_situation  religion  ...  \
# 0                  0.0        5.0                 3.0       1.0  ...
# 1                  0.0        5.0                 3.0       1.0  ...
# 2                  0.0        5.0                 3.0       1.0  ...
# 3                  1.0        5.0                 3.0       1.0  ...
# 4                  0.0        4.0                 2.0       1.0  ...
#
#    spouse_satisfaction  relationship_satisfaction natl_pride_in_parents  \
# 0                  7.0                        7.0        Strongly agree
# 1                  6.0                        6.0        Agree somewhat
# 2                  7.0                        7.0        Agree somewhat
# 3                  6.0                        6.0        Agree slightly
# 4                  6.0                        7.0        Agree slightly
#
#   natl_pride_in_children natl_aging_parents_live_with_children  \
# 0         Strongly agree                        Strongly agree
# 1         Strongly agree                        Strongly agree
# 2         Strongly agree                        Agree somewhat
# 3         Strongly agree                        Strongly agree
# 4         Agree somewhat                        Agree slightly
#
#   natl_children_live_at_home_marraige indv_pride_in_parents  \
# 0                      Strongly agree        Strongly agree
# 1                      Strongly agree        Strongly agree
# 2                      Strongly agree        Strongly agree
# 3                      Agree somewhat        Strongly agree
# 4                      Agree somewhat        Strongly agree
#
#   indv_pride_in_children indv_aging_parents_live_with_children  \
# 0         Strongly agree                        Strongly agree
# 1         Strongly agree                        Strongly agree
# 2         Strongly agree                        Strongly agree
# 3         Strongly agree                        Strongly agree
# 4         Strongly agree                        Strongly agree
#
#   indv_children_live_at_home_marraige
# 0                      Strongly agree
# 1                      Strongly agree
# 2                      Strongly agree
# 3                      Strongly agree
# 4                      Strongly agree
#
# [5 rows x 32 columns]

# %%
data['religion'] = data['religion'].replace({1:"Protestant",2:"Catholic",3:"Jewish",4:"Muslim",5:"Buddhist",6:"None",7:"Jehovah",8:"Evangelic",9:"Spiritualism",10:"Other",11:"Orthodox",12:"Hindu"})

# %%
data['edu_level'] = data['edu_level'].replace({1:"No formal education",2:"Primary school",3:"Secondary school",4:"High school or technical school",5:"Bachelors or Masters degree"})

# %%
data['pension'] = data['pension'].replace(globe_survey_dict)

# %%
data['material_situation'] = data['material_situation'].replace({1:"Much better than average",2:"Better than average",3:"Average",4:"Worse than average",5:"Much worse than average"})

# %%
data.head()
# Out:
#    index  country   sex   age  marriage_duration_years  num_children_total  \
# 0      2  Brazil   Male  21.0                      2.0                 0.0
# 1      3  Brazil   Male  29.0                      3.0                 1.0
# 2      4  Brazil   Male  30.0                      7.0                 0.0
# 3      5  Brazil   Male  30.0                      7.0                 1.0
# 4      6  Brazil   Male  28.0                      9.0                 0.0
#
#    num_children_inhome                        edu_level   material_situation  \
# 0                  0.0      Bachelors or Masters degree              Average
# 1                  0.0      Bachelors or Masters degree              Average
# 2                  0.0      Bachelors or Masters degree              Average
# 3                  1.0      Bachelors or Masters degree              Average
# 4                  0.0  High school or technical school  Better than average
#
#      religion  ...  spouse_satisfaction relationship_satisfaction  \
# 0  Protestant  ...                  7.0                       7.0
# 1  Protestant  ...                  6.0                       6.0
# 2  Protestant  ...                  7.0                       7.0
# 3  Protestant  ...                  6.0                       6.0
# 4  Protestant  ...                  6.0                       7.0
#
#   natl_pride_in_parents natl_pride_in_children  \
# 0        Strongly agree         Strongly agree
# 1        Agree somewhat         Strongly agree
# 2        Agree somewhat         Strongly agree
# 3        Agree slightly         Strongly agree
# 4        Agree slightly         Agree somewhat
#
#   natl_aging_parents_live_with_children natl_children_live_at_home_marraige  \
# 0                        Strongly agree                      Strongly agree
# 1                        Strongly agree                      Strongly agree
# 2                        Agree somewhat                      Strongly agree
# 3                        Strongly agree                      Agree somewhat
# 4                        Agree slightly                      Agree somewhat
#
#   indv_pride_in_parents indv_pride_in_children  \
# 0        Strongly agree         Strongly agree
# 1        Strongly agree         Strongly agree
# 2        Strongly agree         Strongly agree
# 3        Strongly agree         Strongly agree
# 4        Strongly agree         Strongly agree
#
#   indv_aging_parents_live_with_children indv_children_live_at_home_marraige
# 0                        Strongly agree                      Strongly agree
# 1                        Strongly agree                      Strongly agree
# 2                        Strongly agree                      Strongly agree
# 3                        Strongly agree                      Strongly agree
# 4                        Strongly agree                      Strongly agree
#
# [5 rows x 32 columns]
